# %% [markdown]
# ### Combine classificationd data

# %%
print ("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("./Data/1/Classification_Data.csv")
df_1.head(1)
# Out:
#    [1]-Total no of Return statement  [2]-Total no of Control Statement  \
# 0                                 1                                  0
#
#    [3]-Total no of Allocation instruction  [4]-Total no of Load Instructions  \
# 0                                       0                                  1
#
#    [5]-Total no of Store Instructions  \
# 0                                   1
#
#    [6]-Total no of Multiplication (Float Datatype) Operation  \
# 0                                                  0
#
#    [7]-Total no of Addition(Integer Datatype) Instruction  \
# 0                                                  2
#
#    [8]-Total no of Multiplication(Integer Datatype) Instruction  \
# 0                                                  2
#
#    [9]-Total no of Division(Float Datatype) instruction  \
# 0                                                  0
#
#    [10]-Total no of Division(Integer Datatype) instruction  ...  \
# ...

# %%
df_2 = pd.read_csv("./Data/2/Classification_Data.csv")
df_2.head(1)
# Out:
#    [1]-Total no of Return statement  [2]-Total no of Control Statement  \
# 0                                 1                                  3
#
#    [3]-Total no of Allocation instruction  [4]-Total no of Load Instructions  \
# 0                                       0                                  2
#
#    [5]-Total no of Store Instructions  \
# 0                                   1
#
#    [6]-Total no of Multiplication (Float Datatype) Operation  \
# 0                                                  0
#
#    [7]-Total no of Addition(Integer Datatype) Instruction  \
# 0                                                  4
#
#    [8]-Total no of Multiplication(Integer Datatype) Instruction  \
# 0                                                  3
#
#    [9]-Total no of Division(Float Datatype) instruction  \
# 0                                                  0
#
#    [10]-Total no of Division(Integer Datatype) instruction  ...  \
# ...

# %%
df_class = pd.concat( [df_1, df_2  ], axis=0  )
df_class
# Out:
#      [1]-Total no of Return statement  [2]-Total no of Control Statement  \
# 0                                   1                                  0
# 1                                   1                                  0
# 2                                   1                                  0
# 3                                   1                                  0
# 4                                   1                                  0
# ..                                ...                                ...
# 154                                 1                                  0
# 155                                 1                                  0
# 156                                 1                                  0
# 157                                 1                                  0
# 158                                 1                                  0
#
#      [3]-Total no of Allocation instruction  \
# 0                                         0
# ...

# %%
df_class.to_csv("Classification_data.csv", encoding="utf8", index=False)

# %% [markdown]
# ### Combine the regression data

# %%
df_3 = pd.read_csv("./Data/1/Speedup_Data.csv")
df_3.head(1)
# Out:
#    [1]-Total no of Return statement  [2]-Total no of Control Statement  \
# 0                                 1                                  0
#
#    [3]-Total no of Allocation instruction  [4]-Total no of Load Instructions  \
# 0                                       0                                  1
#
#    [5]-Total no of Store Instructions  \
# 0                                   1
#
#    [6]-Total no of Multiplication (Float Datatype) Operation  \
# 0                                                  0
#
#    [7]-Total no of Addition(Integer Datatype) Instruction  \
# 0                                                  2
#
#    [8]-Total no of Multiplication(Integer Datatype) Instruction  \
# 0                                                  2
#
#    [9]-Total no of Division(Float Datatype) instruction  \
# 0                                                  0
#
#    [10]-Total no of Division(Integer Datatype) instruction  ...  \
# ...

# %%
df_4 = pd.read_csv("./Data/2/Speedup_Data.csv")
df_4.head(1)
# Out:
#    [1]-Total no of Return statement  [2]-Total no of Control Statement  \
# 0                                 1                                  3
#
#    [3]-Total no of Allocation instruction  [4]-Total no of Load Instructions  \
# 0                                       0                                  2
#
#    [5]-Total no of Store Instructions  \
# 0                                   1
#
#    [6]-Total no of Multiplication (Float Datatype) Operation  \
# 0                                                  0
#
#    [7]-Total no of Addition(Integer Datatype) Instruction  \
# 0                                                  4
#
#    [8]-Total no of Multiplication(Integer Datatype) Instruction  \
# 0                                                  3
#
#    [9]-Total no of Division(Float Datatype) instruction  \
# 0                                                  0
#
#    [10]-Total no of Division(Integer Datatype) instruction  ...  \
# ...

# %%
df_regr = pd.concat( [df_3, df_4  ], axis=0  )

# %%
df_regr.to_csv("Regression_Data.csv", encoding="utf8", index=False)

# %% [markdown]
# ### Training Classification Model

# %%
data = df_class[  df_class.columns[0:-1] ]
label = df_class[ df_class.columns[-1] ]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( data, label, test_size=0.33, random_state=42)

# %%
from sklearn import datasets
from sklearn.svm import SVC

clf = SVC()
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict( x_test  )

# %%
print ( "Accuracy is : " , len(y_test [ y_pred == y_test ] )/ len(y_test)*100, "%" )
# Out:
# Accuracy is :  77.02702702702703 %

# %%
import pickle

# save the classifier
with open('my_dumped_classifier.pkl', 'wb') as fid:
    pickle.dump( clf, fid)    

# load it again
#with open('my_dumped_classifier.pkl', 'rb') as fid:
    #clf = cPickle.load(fid)

# %% [markdown]
# ### Training Regression Model

# %%
data = df_regr[  df_regr.columns[0:-1] ]
label = df_regr[ df_regr.columns[-1] ]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( data, label, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

regr = RandomForestRegressor(n_estimators=200, max_depth=5, random_state=0)

regr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=200, random_state=0)

# %%
y_pred = regr.predict( x_test )

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error( list( y_test ) , list( y_pred ) )
# Out:
# 12.198527327924685

# %%
import pickle

# save the classifier
with open('my_dumped_regressor.pkl', 'wb') as fid:
    pickle.dump( regr, fid)

# load it again
#with open('my_dumped_regressor.pkl', 'rb') as fid:
    #regr = cPickle.load(fid)
